# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# Objective:
# - Combine and integrate data from multiple sources using merging, concatenating, or joining techniques to generate more comprehensive and meaningful datasets for analysis.
# - Modify the structure of data by pivoting, stacking/unstacking, or melting dataframes, enabling them to efficiently explore and analyze complex datasets.

# %% [markdown]
# # Challenge 1: Combining Data

# %% [markdown]
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv

# %% [markdown]
# Perform data cleaning and formatting using the main cleaning and formatting function created in the previous lab to clean and format the data.

# %% [markdown]
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %% [markdown]
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
# Importing the cleaning functions
import cleaning_functions

# %%
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Applying the main cleaning and formatting function to df and saving the result in a new data frame
df_cleaned=cleaning_functions.general_cleaning(df)
df_cleaned
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                  588174.235      0.0                1000.0
# 1                  697953.590      0.0                  94.0
# 2                 1288743.170  48767.0                 108.0
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
# Applying the main cleaning and formatting function to df2 and saving the result in a new data frame
df2_cleaned=cleaning_functions.general_cleaning(df2)
df2_cleaned
# Out:
#     customer          st gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# Applying the needed cleaning and formatting functions to df3 and saving the result in a new data frame
print("The main cleaning function doesn't work with this data frame because it already has the 'customer lifetime value' and 'number of open complaints' cleaned without symbols, so it raises an error. That's why in this case we have to apply the individual functions to clean and format it. If we check each step, we will see that df3 only needs to standardize the column names for it to be clean. We apply the function previously made for this issue.")
df3_cleaned=cleaning_functions.standardize_column_names(df3)
df3_cleaned
# Out:
# The main cleaning function doesn't work with this data frame because it already has the 'customer lifetime value' and 'number of open complaints' cleaned without symbols, so it raises an error. That's why in this case we have to apply the individual functions to clean and format it. If we check each step, we will see that df3 only needs to standardize the column names for it to be clean. We apply the function previously made for this issue.
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# ...

# %%
# Displaying each cleaned data frame's columns' names to check they are in the same order 
display(df_cleaned.columns)
display(df2_cleaned.columns)
display(df3_cleaned.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
# Changing df2_cleaned's columns' order to match the one in df_cleaned
df2_cleaned=df2_cleaned[['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]
df2_cleaned
# Out:
#     customer          st gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
# Changing df3_cleaned's columns' names and order to match df_cleaned and df2_cleaned
df3_cleaned.rename(columns={'state':'st'},inplace=True)
df3_cleaned=df3_cleaned[['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]
df3_cleaned
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
# Combining df_clenaed, df2_cleaned and df3_cleaned in the same data frame
customer_data=pd.concat([df_cleaned,df2_cleaned,df3_cleaned],axis=0,ignore_index=True)
customer_data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9132  LA72316  California      M              Bachelor
# 9133  PK87824  California      F               College
# 9134  TD14365  California      M              Bachelor
# 9135  UP19263  California      M               College
# 9136  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                5.881742e+05      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %%
# Verifying that customer_data has all the row from the three datasets
df_cleaned.shape[0]+df2_cleaned.shape[0]+df3_cleaned.shape[0]==customer_data.shape[0]
# Out:
# True

# %%
# Dropping duplicate rows based in the 'customer' column
print("After combining the data frames, there were some rows that had the same customer ID. Those rows had the same values in each cell except one, the 'customer_lifetime_value', that in the second duplicated row had the decimal separator some positions offset to the right. That's why in the next step the duplicated rows that are not the first one are dropped.")
customer_data.drop_duplicates(subset=['customer'],inplace=True,ignore_index=True)
customer_data
# Out:
# After combining the data frames, there were some rows that had the same customer ID. Those rows had the same values in each cell except one, the 'customer_lifetime_value', that in the second duplicated row had the decimal separator some positions offset to the right. That's why in the next step the duplicated rows that are not the first one are dropped.
#      customer          st gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9051  LA72316  California      M              Bachelor
# 9052  PK87824  California      F               College
# 9053  TD14365  California      M              Bachelor
# 9054  UP19263  California      M               College
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %% [markdown]
# ## Exercise 1: Clean and Format the Data

# %% [markdown]
# While the dataset has been partially cleaned and formatted, we still need to perform several data cleaning tasks. Specifically, we need to standardize the column names, clean null values, convert the effective_to_date column to datetime, and extract the months from the dataset and store them in a separate column.
#
# To accomplish these tasks, we will use the functions created in the previous step to standardize the column names and deal with null values, and then we will apply additional functions to convert the effective_to_date column to datetime and extract the months.
#
# Save the clean dataset into a csv file.

# %%
marketing_customer_analysis = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')
marketing_customer_analysis
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
# Standardizing the column names
print("The main cleaning function doesn't work with this data frame because it already has the 'customer lifetime value' and 'number of open complaints' cleaned without symbols, so it raises an error. That's why in this case we have to apply the individual functions to clean and format it.")
marketing_customer_analysis = cleaning_functions.standardize_column_names(marketing_customer_analysis)
marketing_customer_analysis
# Out:
# The main cleaning function doesn't work with this data frame because it already has the 'customer lifetime value' and 'number of open complaints' cleaned without symbols, so it raises an error. That's why in this case we have to apply the individual functions to clean and format it.
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# ...

# %%
# Checking the rows in which there are null values
marketing_customer_analysis.isnull().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
# Cleaning null values
marketing_customer_analysis = cleaning_functions.drop_row_all_null(marketing_customer_analysis)
marketing_customer_analysis = cleaning_functions.replace_null_categorical(marketing_customer_analysis,'state')
marketing_customer_analysis = cleaning_functions.replace_null_categorical(marketing_customer_analysis,'response')
marketing_customer_analysis = cleaning_functions.replace_null_categorical(marketing_customer_analysis,'vehicle_class')
marketing_customer_analysis = cleaning_functions.replace_null_categorical(marketing_customer_analysis,'vehicle_size')
marketing_customer_analysis = cleaning_functions.replace_null_categorical(marketing_customer_analysis,'vehicle_type')
marketing_customer_analysis = cleaning_functions.replace_null_numerical_median(marketing_customer_analysis,'months_since_last_claim')
marketing_customer_analysis = cleaning_functions.replace_null_numerical_median(marketing_customer_analysis,'number_of_open_complaints')
marketing_customer_analysis
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  Washington              6857.519928      Yes
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
# Checking if the null values have been properly cleaned
marketing_customer_analysis.isnull().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %%
# Converting the effective_to_date column to datetime
marketing_customer_analysis['effective_to_date'] = pd.to_datetime(marketing_customer_analysis['effective_to_date'], errors='coerce')
marketing_customer_analysis['effective_to_date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
# Checking the effective_to_date column's type has been properly changed
marketing_customer_analysis.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# ...

# %%
# Extracting the months from the dataset and storing them in a separate column
months=[]
for i in marketing_customer_analysis['effective_to_date'].keys():
    months.append(marketing_customer_analysis['effective_to_date'][i].month)
marketing_customer_analysis['months']=months
marketing_customer_analysis
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  Washington              6857.519928      Yes
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
# Saving the clean dataset to a new CSV file
marketing_customer_analysis.to_csv('clean_marketing_customer_analysis.csv',index = False)

# %% [markdown]
# ## Exercise 2: Structuring Data

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# 3. You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# 1.Summary table showing the total revenue for each sales channel 
display(marketing_customer_analysis.pivot_table(values=['customer_lifetime_value'],index=['sales_channel'],aggfunc={'customer_lifetime_value':'sum'}).round(decimals=2))
print("As in the exercise statement it isn't specified the time period they want, I used the column customer_lifetime_value as total revenue because of its description: estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company.")
print("Looking at this table we can see that the sales channel that brought the most sales in terms of total revenue is Agent, while the channel that brought the least is Web.")
# Out:
#                customer_lifetime_value
# sales_channel
# Agent                      33057887.85
# Branch                     24359201.21
# Call Center                17364288.37
# Web                        12697632.90
# As in the exercise statement it isn't specified the time period they want, I used the column customer_lifetime_value as total revenue because of its description: estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company.
# Looking at this table we can see that the sales channel that brought the most sales in terms of total revenue is Agent, while the channel that brought the least is Web.

# %%
# 2. Pivot table that shows the average customer lifetime value per gender and education level
display(marketing_customer_analysis.pivot_table(values=['customer_lifetime_value'],index=['gender','education']))
print("Looking at this table we can see that, for females, the highest average customer lifetime value belongs to the individuals with an educational level of high school or below. In the male case, it belongs to the Master category, but is closeliy followed by high school or below. The lowest average customer lifetime value for females belongs to the Doctor category, as well as for males.")
# Out:
#                              customer_lifetime_value
# gender education
# F      Bachelor                          7874.269478
#        College                           7748.823325
#        Doctor                            7328.508916
#        High School or Below              8675.220201
#        Master                            8157.053154
# M      Bachelor                          7703.601675
#        College                           8052.459288
#        Doctor                            7415.333638
#        High School or Below              8149.687783
#        Master                            8168.832659
# ...

# %%
# 3. Summary table showing the number of complaints by policy type and month
complaints_policy_month=marketing_customer_analysis.groupby(['policy_type','months'])[['number_of_open_complaints']].sum().reset_index()
complaints_policy_month.pivot(index='policy_type',columns='months')
# Out:
#                number_of_open_complaints
# months                                 1       2
# policy_type
# Corporate Auto                     415.0   361.0
# Personal Auto                     1635.0  1363.0
# Special Auto                        84.0    91.0
